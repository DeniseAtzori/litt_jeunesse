# %% [markdown]
# # Calcolo la TF-IDF come rappresentazione dei personaggi

# %% [markdown]
# Un documento -> un dizionario personaggio estratto da Propp

# %% [markdown]
# ### Lettura file (con limite a 5 personaggi)

# %%
def read_booknlp(path_book):
    with open(path_book, "r", encoding="utf-8") as file:
        lines = file.readlines()
        dicts = [eval(line.strip()) for line in lines if line.strip()]
    return dicts[:5]   # mantengo i primi 5 personaggi

# %% [markdown]
# ### Estrazione parole da un personaggio

# %%
def extract_words_from_character(char_dict):
    words = []
    
    for key in ['agent', 'patient', 'mod', 'poss']:
        if key in char_dict:
            words.extend([item['w'] for item in char_dict[key]])
    
    return words

# %% [markdown]
# ### Costruzione dei documenti dei personaggi

# %%
documents = []
metadata = []

# %%
import glob
import os

book_files = glob.glob(os.path.join("Corpus_propp", "*.book"))

for filepath in book_files:
    filename = os.path.basename(filepath)
    book_data = read_booknlp(filepath)  # già limitato a [:5]
    
    for idx, char_dict in enumerate(book_data):
        
        # --------- TESTO DEL PERSONAGGIO ---------
        words = []
        for key_field in ['agent', 'patient', 'mod', 'poss']:
            if key_field in char_dict:
                words.extend([item['w'] for item in char_dict[key_field]])
        
        documents.append(" ".join(words))  # TF-IDF vuole stringhe
        
        # --------- GENDER ---------
        if char_dict['gender'].get("argmax") == "Female":
            gender_label = 1
        else:
            gender_label = 0
        
        # --------- NOME PERSONAGGIO ---------
        if (
            "mentions" in char_dict and
            char_dict["mentions"].get("proper") and
            len(char_dict["mentions"]["proper"]) > 0
        ):
            char_name = char_dict["mentions"]["proper"][0]["n"].lower()
        else:
            char_name = f"char{idx+1}"
        
        metadata.append({
            "filename": filename,
            "character_name": char_name,
            "gender": gender_label
        })

# %% [markdown]
# ## Salvataggio delle parole per ogni personaggio in un csv

# %%
import pandas as pd

rows = []

for i in range(len(documents)):
    filename = metadata[i]["filename"]
    print(filename)
    character_name = metadata[i]["character_name"]
    row = {
        "title" : f"{filename} --- {character_name}",
        "author_gender" : "",
        "Gender": metadata[i]["gender"],
        "type" : "",
        "text": documents[i]
    }
    rows.append(row)

df = pd.DataFrame(rows)
# Out:
# 1883_Halt-Marie-Robert_Histoire-d-un-petit-homme.book
# 1883_Halt-Marie-Robert_Histoire-d-un-petit-homme.book
# 1883_Halt-Marie-Robert_Histoire-d-un-petit-homme.book
# 1883_Halt-Marie-Robert_Histoire-d-un-petit-homme.book
# 1883_Halt-Marie-Robert_Histoire-d-un-petit-homme.book
# 1867_Sauquet-Victor_L-Enfant-des-montagnes.book
# 1867_Sauquet-Victor_L-Enfant-des-montagnes.book
# 1867_Sauquet-Victor_L-Enfant-des-montagnes.book
# 1867_Sauquet-Victor_L-Enfant-des-montagnes.book
# 1867_Sauquet-Victor_L-Enfant-des-montagnes.book
# 1874_Stolz-Madame-de_Les-Poches-de-mon-oncle.book
# 1874_Stolz-Madame-de_Les-Poches-de-mon-oncle.book
# 1874_Stolz-Madame-de_Les-Poches-de-mon-oncle.book
# 1874_Stolz-Madame-de_Les-Poches-de-mon-oncle.book
# 1874_Stolz-Madame-de_Les-Poches-de-mon-oncle.book
# 1887_Malot-Hector_Sans-famille.book
# 1887_Malot-Hector_Sans-famille.book
# 1887_Malot-Hector_Sans-famille.book
# 1887_Malot-Hector_Sans-famille.book
# 1887_Malot-Hector_Sans-famille.book
# 1868_Gouraud-Julie_L-Enfant-du-guide.book
# 1868_Gouraud-Julie_L-Enfant-du-guide.book
# 1868_Gouraud-Julie_L-Enfant-du-guide.book
# 1868_Gouraud-Julie_L-Enfant-du-guide.book
# 1868_Gouraud-Julie_L-Enfant-du-guide.book
# 1882_Fleuriot-Zenaide_Bouche-en-coeur.book
# 1882_Fleuriot-Zenaide_Bouche-en-coeur.book
# 1882_Fleuriot-Zenaide_Bouche-en-coeur.book
# 1882_Fleuriot-Zenaide_Bouche-en-coeur.book
# 1882_Fleuriot-Zenaide_Bouche-en-coeur.book
# 1859_Segur-comtesse-de_Les-Vacances.book
# 1859_Segur-comtesse-de_Les-Vacances.book
# 1859_Segur-comtesse-de_Les-Vacances.book
# 1859_Segur-comtesse-de_Les-Vacances.book
# 1859_Segur-comtesse-de_Les-Vacances.book
# 1880_Martignat-Mlle-de_L-Oncle-Boni.book
# 1880_Martignat-Mlle-de_L-Oncle-Boni.book
# 1880_Martignat-Mlle-de_L-Oncle-Boni.book
# 1880_Martignat-Mlle-de_L-Oncle-Boni.book
# 1880_Martignat-Mlle-de_L-Oncle-Boni.book
# 1906_Morin-Louis_Grand-mere-avait-des-defauts-.book
# 1906_Morin-Louis_Grand-mere-avait-des-defauts-.book
# 1906_Morin-Louis_Grand-mere-avait-des-defauts-.book
# 1906_Morin-Louis_Grand-mere-avait-des-defauts-.book
# 1906_Morin-Louis_Grand-mere-avait-des-defauts-.book
# 1901_Mael-Pierre_Un-mousse-de-Surcouf.book
# 1901_Mael-Pierre_Un-mousse-de-Surcouf.book
# 1901_Mael-Pierre_Un-mousse-de-Surcouf.book
# 1901_Mael-Pierre_Un-mousse-de-Surcouf.book
# 1901_Mael-Pierre_Un-mousse-de-Surcouf.book
# 1874_Fleuriot-Zenaide_Armelle-Trahec.book
# 1874_Fleuriot-Zenaide_Armelle-Trahec.book
# 1874_Fleuriot-Zenaide_Armelle-Trahec.book
# 1874_Fleuriot-Zenaide_Armelle-Trahec.book
# 1874_Fleuriot-Zenaide_Armelle-Trahec.book
# 1890_Dombre-Roger_Une-pupille-genante.book
# 1890_Dombre-Roger_Une-pupille-genante.book
# 1890_Dombre-Roger_Une-pupille-genante.book
# 1890_Dombre-Roger_Une-pupille-genante.book
# 1890_Dombre-Roger_Une-pupille-genante.book
# 1875_Legouve-Ernest_Nos-filles-et-nos-fils-scenes-et-etudes-de-famille.book
# 1875_Legouve-Ernest_Nos-filles-et-nos-fils-scenes-et-etudes-de-famille.book
# 1875_Legouve-Ernest_Nos-filles-et-nos-fils-scenes-et-etudes-de-famille.book
# 1875_Legouve-Ernest_Nos-filles-et-nos-fils-scenes-et-etudes-de-famille.book
# 1875_Legouve-Ernest_Nos-filles-et-nos-fils-scenes-et-etudes-de-famille.book
# 1885_Amero-Constant_Le-tour-de-France-d-un-petit-Parisien.book
# 1885_Amero-Constant_Le-tour-de-France-d-un-petit-Parisien.book
# 1885_Amero-Constant_Le-tour-de-France-d-un-petit-Parisien.book
# 1885_Amero-Constant_Le-tour-de-France-d-un-petit-Parisien.book
# 1885_Amero-Constant_Le-tour-de-France-d-un-petit-Parisien.book
# 1880_Fleuriot-Zenaide_Bonasse.book
# 1880_Fleuriot-Zenaide_Bonasse.book
# 1880_Fleuriot-Zenaide_Bonasse.book
# 1880_Fleuriot-Zenaide_Bonasse.book
# 1880_Fleuriot-Zenaide_Bonasse.book
# 1854_Bassanville-Anais-de_Les-Primeurs-de-la-vie-ou-Bonheurs-joies-et-douleurs-de-la-jeunesse.book
# 1854_Bassanville-Anais-de_Les-Primeurs-de-la-vie-ou-Bonheurs-joies-et-douleurs-de-la-jeunesse.book
# 1854_Bassanville-Anais-de_Les-Primeurs-de-la-vie-ou-Bonheurs-joies-et-douleurs-de-la-jeunesse.book
# 1854_Bassanville-Anais-de_Les-Primeurs-de-la-vie-ou-Bonheurs-joies-et-douleurs-de-la-jeunesse.book
# 1854_Bassanville-Anais-de_Les-Primeurs-de-la-vie-ou-Bonheurs-joies-et-douleurs-de-la-jeunesse.book
# 1926_Mac-Orlan-Pierre_Les-clients-du-Bon-Chien-Jaune.book
# 1926_Mac-Orlan-Pierre_Les-clients-du-Bon-Chien-Jaune.book
# 1926_Mac-Orlan-Pierre_Les-clients-du-Bon-Chien-Jaune.book
# 1926_Mac-Orlan-Pierre_Les-clients-du-Bon-Chien-Jaune.book
# 1926_Mac-Orlan-Pierre_Les-clients-du-Bon-Chien-Jaune.book
# 1882_Gouraud-Julie_Chez-grand-mere.book
# 1882_Gouraud-Julie_Chez-grand-mere.book
# 1882_Gouraud-Julie_Chez-grand-mere.book
# 1882_Gouraud-Julie_Chez-grand-mere.book
# 1882_Gouraud-Julie_Chez-grand-mere.book
# 1893_Malot-Hector_En-Famille.book
# 1893_Malot-Hector_En-Famille.book
# 1893_Malot-Hector_En-Famille.book
# 1893_Malot-Hector_En-Famille.book
# 1893_Malot-Hector_En-Famille.book
# 1881_Colomb-Josephine_Feu-de-paille.book
# 1881_Colomb-Josephine_Feu-de-paille.book
# 1881_Colomb-Josephine_Feu-de-paille.book
# 1881_Colomb-Josephine_Feu-de-paille.book
# 1881_Colomb-Josephine_Feu-de-paille.book
# 1873_Gouraud-Julie_Petite-et-grande.book
# 1873_Gouraud-Julie_Petite-et-grande.book
# 1873_Gouraud-Julie_Petite-et-grande.book
# 1873_Gouraud-Julie_Petite-et-grande.book
# 1873_Gouraud-Julie_Petite-et-grande.book
# 1881_Fleuriot-Zenaide_Alberte.book
# 1881_Fleuriot-Zenaide_Alberte.book
# 1881_Fleuriot-Zenaide_Alberte.book
# 1881_Fleuriot-Zenaide_Alberte.book
# 1881_Fleuriot-Zenaide_Alberte.book
# 1895_Mael-Pierre_Les-Derniers-Hommes-rouges.book
# 1895_Mael-Pierre_Les-Derniers-Hommes-rouges.book
# 1895_Mael-Pierre_Les-Derniers-Hommes-rouges.book
# 1895_Mael-Pierre_Les-Derniers-Hommes-rouges.book
# 1895_Mael-Pierre_Les-Derniers-Hommes-rouges.book
# 1878_Gouraud-Julie_Cousine-Marie.book
# 1878_Gouraud-Julie_Cousine-Marie.book
# 1878_Gouraud-Julie_Cousine-Marie.book
# 1878_Gouraud-Julie_Cousine-Marie.book
# 1878_Gouraud-Julie_Cousine-Marie.book
# 1851_Sand-George_Histoire-du-veritable-Gribouille.book
# 1851_Sand-George_Histoire-du-veritable-Gribouille.book
# 1851_Sand-George_Histoire-du-veritable-Gribouille.book
# 1851_Sand-George_Histoire-du-veritable-Gribouille.book
# 1851_Sand-George_Histoire-du-veritable-Gribouille.book
# 1867_Pitray-Olga-de-Segur_Les-enfants-des-Tuileries.book
# 1867_Pitray-Olga-de-Segur_Les-enfants-des-Tuileries.book
# 1867_Pitray-Olga-de-Segur_Les-enfants-des-Tuileries.book
# 1867_Pitray-Olga-de-Segur_Les-enfants-des-Tuileries.book
# 1867_Pitray-Olga-de-Segur_Les-enfants-des-Tuileries.book
# 1875_Mirabeau-Marie-Le-Harivel-de-Gonneville_Ctesse-de-Mirabeau-Jane-et-Germaine-Voyages-d-un-capitaine.book
# 1875_Mirabeau-Marie-Le-Harivel-de-Gonneville_Ctesse-de-Mirabeau-Jane-et-Germaine-Voyages-d-un-capitaine.book
# 1875_Mirabeau-Marie-Le-Harivel-de-Gonneville_Ctesse-de-Mirabeau-Jane-et-Germaine-Voyages-d-un-capitaine.book
# 1875_Mirabeau-Marie-Le-Harivel-de-Gonneville_Ctesse-de-Mirabeau-Jane-et-Germaine-Voyages-d-un-capitaine.book
# 1875_Mirabeau-Marie-Le-Harivel-de-Gonneville_Ctesse-de-Mirabeau-Jane-et-Germaine-Voyages-d-un-capitaine.book
# 1891_Witt-Henriette-de_La-Petite-fille-aux-grand-meres.book
# 1891_Witt-Henriette-de_La-Petite-fille-aux-grand-meres.book
# 1891_Witt-Henriette-de_La-Petite-fille-aux-grand-meres.book
# 1891_Witt-Henriette-de_La-Petite-fille-aux-grand-meres.book
# 1891_Witt-Henriette-de_La-Petite-fille-aux-grand-meres.book
# 1878_Chavannes-de-La-Giraudiere-Hippolyte-de_Patrice.book
# 1878_Chavannes-de-La-Giraudiere-Hippolyte-de_Patrice.book
# 1878_Chavannes-de-La-Giraudiere-Hippolyte-de_Patrice.book
# 1878_Chavannes-de-La-Giraudiere-Hippolyte-de_Patrice.book
# 1878_Chavannes-de-La-Giraudiere-Hippolyte-de_Patrice.book
# 1900_Chabrier-Rieder-Charlotte_Les-epreuves-de-Charlotte.book
# 1900_Chabrier-Rieder-Charlotte_Les-epreuves-de-Charlotte.book
# 1900_Chabrier-Rieder-Charlotte_Les-epreuves-de-Charlotte.book
# 1900_Chabrier-Rieder-Charlotte_Les-epreuves-de-Charlotte.book
# 1900_Chabrier-Rieder-Charlotte_Les-epreuves-de-Charlotte.book
# 1867_Pressense-Elise-de_Deux-ans-au-lycee.book
# 1867_Pressense-Elise-de_Deux-ans-au-lycee.book
# 1867_Pressense-Elise-de_Deux-ans-au-lycee.book
# 1867_Pressense-Elise-de_Deux-ans-au-lycee.book
# 1867_Pressense-Elise-de_Deux-ans-au-lycee.book
# 1843_Desnoyers-Louis_Les-aventures-de-Jean-Paul-Choppart.book
# 1843_Desnoyers-Louis_Les-aventures-de-Jean-Paul-Choppart.book
# 1843_Desnoyers-Louis_Les-aventures-de-Jean-Paul-Choppart.book
# 1843_Desnoyers-Louis_Les-aventures-de-Jean-Paul-Choppart.book
# 1843_Desnoyers-Louis_Les-aventures-de-Jean-Paul-Choppart.book
# 1910_Graffigny-H-de_Le-tour-de-France-en-aeroplane.book
# 1910_Graffigny-H-de_Le-tour-de-France-en-aeroplane.book
# 1910_Graffigny-H-de_Le-tour-de-France-en-aeroplane.book
# 1910_Graffigny-H-de_Le-tour-de-France-en-aeroplane.book
# 1910_Graffigny-H-de_Le-tour-de-France-en-aeroplane.book
# 1889_La-Brete-Jean-de_Mon-oncle-et-mon-cure.book
# 1889_La-Brete-Jean-de_Mon-oncle-et-mon-cure.book
# 1889_La-Brete-Jean-de_Mon-oncle-et-mon-cure.book
# 1889_La-Brete-Jean-de_Mon-oncle-et-mon-cure.book
# 1889_La-Brete-Jean-de_Mon-oncle-et-mon-cure.book
# 1866_Segur-comtesse-de_Un-Bon-Petit-Diable.book
# 1866_Segur-comtesse-de_Un-Bon-Petit-Diable.book
# 1866_Segur-comtesse-de_Un-Bon-Petit-Diable.book
# 1866_Segur-comtesse-de_Un-Bon-Petit-Diable.book
# 1866_Segur-comtesse-de_Un-Bon-Petit-Diable.book
# 1911_Marchal-Gustave_Tante-Meteore.book
# 1911_Marchal-Gustave_Tante-Meteore.book
# 1911_Marchal-Gustave_Tante-Meteore.book
# 1911_Marchal-Gustave_Tante-Meteore.book
# 1911_Marchal-Gustave_Tante-Meteore.book
# 1872_Gouraud-Julie_Le-Livre-de-maman.book
# 1872_Gouraud-Julie_Le-Livre-de-maman.book
# 1872_Gouraud-Julie_Le-Livre-de-maman.book
# 1872_Gouraud-Julie_Le-Livre-de-maman.book
# 1872_Gouraud-Julie_Le-Livre-de-maman.book
# 1876_Chazel-Prosper_Le-Chalet-des-sapins.book
# 1876_Chazel-Prosper_Le-Chalet-des-sapins.book
# 1876_Chazel-Prosper_Le-Chalet-des-sapins.book
# 1876_Chazel-Prosper_Le-Chalet-des-sapins.book
# 1876_Chazel-Prosper_Le-Chalet-des-sapins.book
# 1925_Robida-Albert_Un-chalet-dans-les-airs.book
# 1925_Robida-Albert_Un-chalet-dans-les-airs.book
# 1925_Robida-Albert_Un-chalet-dans-les-airs.book
# 1925_Robida-Albert_Un-chalet-dans-les-airs.book
# 1925_Robida-Albert_Un-chalet-dans-les-airs.book
# 1897_Gerald-Montmeril_Chryseis-au-desert.book
# 1897_Gerald-Montmeril_Chryseis-au-desert.book
# 1897_Gerald-Montmeril_Chryseis-au-desert.book
# 1897_Gerald-Montmeril_Chryseis-au-desert.book
# 1897_Gerald-Montmeril_Chryseis-au-desert.book
# 1889_Dombre-Roger_Folla.book
# 1889_Dombre-Roger_Folla.book
# 1889_Dombre-Roger_Folla.book
# 1889_Dombre-Roger_Folla.book
# 1889_Dombre-Roger_Folla.book
# 1878_Dupuis-Eudoxie_Cyprienne-et-Cyprien.book
# 1878_Dupuis-Eudoxie_Cyprienne-et-Cyprien.book
# 1878_Dupuis-Eudoxie_Cyprienne-et-Cyprien.book
# 1878_Dupuis-Eudoxie_Cyprienne-et-Cyprien.book
# 1878_Dupuis-Eudoxie_Cyprienne-et-Cyprien.book
# 1858_Gouraud-Julie_Les-Vacances-d-Yvonne.book
# 1858_Gouraud-Julie_Les-Vacances-d-Yvonne.book
# 1858_Gouraud-Julie_Les-Vacances-d-Yvonne.book
# 1858_Gouraud-Julie_Les-Vacances-d-Yvonne.book
# 1858_Gouraud-Julie_Les-Vacances-d-Yvonne.book
# 1874_Witt-Henriette-de_Une-soeur.book
# 1874_Witt-Henriette-de_Une-soeur.book
# 1874_Witt-Henriette-de_Une-soeur.book
# 1874_Witt-Henriette-de_Une-soeur.book
# 1874_Witt-Henriette-de_Une-soeur.book
# 1845_Dumas-Alexandre_Histoire-d-un-Casse-noisette.book
# 1845_Dumas-Alexandre_Histoire-d-un-Casse-noisette.book
# 1845_Dumas-Alexandre_Histoire-d-un-Casse-noisette.book
# 1845_Dumas-Alexandre_Histoire-d-un-Casse-noisette.book
# 1845_Dumas-Alexandre_Histoire-d-un-Casse-noisette.book
# 1888_Gouraud-Julie_Quand-je-serai-grande.book
# 1888_Gouraud-Julie_Quand-je-serai-grande.book
# 1888_Gouraud-Julie_Quand-je-serai-grande.book
# 1888_Gouraud-Julie_Quand-je-serai-grande.book
# 1888_Gouraud-Julie_Quand-je-serai-grande.book
# 1903_Chabrier-Rieder-Charlotte_Les-Enfants-du-Luxembourg.book
# 1903_Chabrier-Rieder-Charlotte_Les-Enfants-du-Luxembourg.book
# 1903_Chabrier-Rieder-Charlotte_Les-Enfants-du-Luxembourg.book
# 1903_Chabrier-Rieder-Charlotte_Les-Enfants-du-Luxembourg.book
# 1903_Chabrier-Rieder-Charlotte_Les-Enfants-du-Luxembourg.book
# 1907_Mael-Pierre_Le-Forban-noir.book
# 1907_Mael-Pierre_Le-Forban-noir.book
# 1907_Mael-Pierre_Le-Forban-noir.book
# 1907_Mael-Pierre_Le-Forban-noir.book
# 1907_Mael-Pierre_Le-Forban-noir.book
# 1860_Segur-comtesse-de_Les-Memoires-d-un-ane.book
# 1860_Segur-comtesse-de_Les-Memoires-d-un-ane.book
# 1860_Segur-comtesse-de_Les-Memoires-d-un-ane.book
# 1860_Segur-comtesse-de_Les-Memoires-d-un-ane.book
# 1860_Segur-comtesse-de_Les-Memoires-d-un-ane.book
# 1863_Farrenc-Cesarie_La-jalousie.book
# 1863_Farrenc-Cesarie_La-jalousie.book
# 1863_Farrenc-Cesarie_La-jalousie.book
# 1863_Farrenc-Cesarie_La-jalousie.book
# 1863_Farrenc-Cesarie_La-jalousie.book
# 1843_Woillez-Catherine_Leontine-et-Marie-ou-les-Deux-educations.book
# 1843_Woillez-Catherine_Leontine-et-Marie-ou-les-Deux-educations.book
# 1843_Woillez-Catherine_Leontine-et-Marie-ou-les-Deux-educations.book
# 1843_Woillez-Catherine_Leontine-et-Marie-ou-les-Deux-educations.book
# 1843_Woillez-Catherine_Leontine-et-Marie-ou-les-Deux-educations.book
# 1858_Segur-comtesse-de_Les-Petites-Filles-Modeles.book
# 1858_Segur-comtesse-de_Les-Petites-Filles-Modeles.book
# 1858_Segur-comtesse-de_Les-Petites-Filles-Modeles.book
# 1858_Segur-comtesse-de_Les-Petites-Filles-Modeles.book
# 1858_Segur-comtesse-de_Les-Petites-Filles-Modeles.book
# 1910_Cim-Albert_Le-petit-Leveille.book
# 1910_Cim-Albert_Le-petit-Leveille.book
# 1910_Cim-Albert_Le-petit-Leveille.book
# 1910_Cim-Albert_Le-petit-Leveille.book
# 1910_Cim-Albert_Le-petit-Leveille.book
# 1876_Gouraud-Julie_Les-Filles-du-professeur.book
# 1876_Gouraud-Julie_Les-Filles-du-professeur.book
# 1876_Gouraud-Julie_Les-Filles-du-professeur.book
# 1876_Gouraud-Julie_Les-Filles-du-professeur.book
# 1876_Gouraud-Julie_Les-Filles-du-professeur.book
# 1888_Blandy-Stella_L-Oncle-Philibert.book
# 1888_Blandy-Stella_L-Oncle-Philibert.book
# 1888_Blandy-Stella_L-Oncle-Philibert.book
# 1888_Blandy-Stella_L-Oncle-Philibert.book
# 1888_Blandy-Stella_L-Oncle-Philibert.book
# 1866_Muller-Rene_Les-Enfants-gates.book
# 1866_Muller-Rene_Les-Enfants-gates.book
# 1866_Muller-Rene_Les-Enfants-gates.book
# 1866_Muller-Rene_Les-Enfants-gates.book
# 1866_Muller-Rene_Les-Enfants-gates.book
# 1897_Mael-Pierre_Au-pays-du-mystere.book
# 1897_Mael-Pierre_Au-pays-du-mystere.book
# 1897_Mael-Pierre_Au-pays-du-mystere.book
# 1897_Mael-Pierre_Au-pays-du-mystere.book
# 1897_Mael-Pierre_Au-pays-du-mystere.book
# 1887_Soboleska-Mme_Les-Jeunes-filles-de-Quinnebasset.book
# 1887_Soboleska-Mme_Les-Jeunes-filles-de-Quinnebasset.book
# 1887_Soboleska-Mme_Les-Jeunes-filles-de-Quinnebasset.book
# 1887_Soboleska-Mme_Les-Jeunes-filles-de-Quinnebasset.book
# 1887_Soboleska-Mme_Les-Jeunes-filles-de-Quinnebasset.book
# 1862_Segur-comtesse-de_La-soeur-de-Gribouille.book
# 1862_Segur-comtesse-de_La-soeur-de-Gribouille.book
# 1862_Segur-comtesse-de_La-soeur-de-Gribouille.book
# 1862_Segur-comtesse-de_La-soeur-de-Gribouille.book
# 1862_Segur-comtesse-de_La-soeur-de-Gribouille.book
# 1866_Segur-comtesse-de_Jean-qui-grogne-et-Jean-qui-rit.book
# 1866_Segur-comtesse-de_Jean-qui-grogne-et-Jean-qui-rit.book
# 1866_Segur-comtesse-de_Jean-qui-grogne-et-Jean-qui-rit.book
# 1866_Segur-comtesse-de_Jean-qui-grogne-et-Jean-qui-rit.book
# 1866_Segur-comtesse-de_Jean-qui-grogne-et-Jean-qui-rit.book
# 1897_Margueritte-Victor_Poum_(aventures-d-un-petit-garçon).book
# 1897_Margueritte-Victor_Poum_(aventures-d-un-petit-garçon).book
# 1897_Margueritte-Victor_Poum_(aventures-d-un-petit-garçon).book
# 1897_Margueritte-Victor_Poum_(aventures-d-un-petit-garçon).book
# 1897_Margueritte-Victor_Poum_(aventures-d-un-petit-garçon).book
# 1855_Solignac-Armand-de_Le-Gateau-des-rois-souvenirs-d-enfance.book
# 1855_Solignac-Armand-de_Le-Gateau-des-rois-souvenirs-d-enfance.book
# 1855_Solignac-Armand-de_Le-Gateau-des-rois-souvenirs-d-enfance.book
# 1855_Solignac-Armand-de_Le-Gateau-des-rois-souvenirs-d-enfance.book
# 1855_Solignac-Armand-de_Le-Gateau-des-rois-souvenirs-d-enfance.book
# 1867_Houssaye-Arsene_La-Pantoufle-de-Cendrillon-ou-Suzanne-aux-coquelicots.book
# 1867_Houssaye-Arsene_La-Pantoufle-de-Cendrillon-ou-Suzanne-aux-coquelicots.book
# 1867_Houssaye-Arsene_La-Pantoufle-de-Cendrillon-ou-Suzanne-aux-coquelicots.book
# 1867_Houssaye-Arsene_La-Pantoufle-de-Cendrillon-ou-Suzanne-aux-coquelicots.book
# 1867_Houssaye-Arsene_La-Pantoufle-de-Cendrillon-ou-Suzanne-aux-coquelicots.book
# 1896_Gyp_Bijou.book
# 1896_Gyp_Bijou.book
# 1896_Gyp_Bijou.book
# 1896_Gyp_Bijou.book
# 1896_Gyp_Bijou.book
# 1864_Segur-comtesse-de_François-le-Bossu.book
# 1864_Segur-comtesse-de_François-le-Bossu.book
# 1864_Segur-comtesse-de_François-le-Bossu.book
# 1864_Segur-comtesse-de_François-le-Bossu.book
# 1864_Segur-comtesse-de_François-le-Bossu.book
# 1885_Bazin-Rene_Ma-tante-Giron.book
# 1885_Bazin-Rene_Ma-tante-Giron.book
# 1885_Bazin-Rene_Ma-tante-Giron.book
# 1885_Bazin-Rene_Ma-tante-Giron.book
# 1885_Bazin-Rene_Ma-tante-Giron.book
# 1858_Segur-comtesse-de_Les-Malheurs-de-Sophie.book
# 1858_Segur-comtesse-de_Les-Malheurs-de-Sophie.book
# 1858_Segur-comtesse-de_Les-Malheurs-de-Sophie.book
# 1858_Segur-comtesse-de_Les-Malheurs-de-Sophie.book
# 1858_Segur-comtesse-de_Les-Malheurs-de-Sophie.book
# 1873_Pressense-Elise-de_Un-petit-monde-d-enfants.book
# 1873_Pressense-Elise-de_Un-petit-monde-d-enfants.book
# 1873_Pressense-Elise-de_Un-petit-monde-d-enfants.book
# 1873_Pressense-Elise-de_Un-petit-monde-d-enfants.book
# 1873_Pressense-Elise-de_Un-petit-monde-d-enfants.book
# 1893_Marie-Delorme_Les-Filles-du-clown.book
# 1893_Marie-Delorme_Les-Filles-du-clown.book
# 1893_Marie-Delorme_Les-Filles-du-clown.book
# 1893_Marie-Delorme_Les-Filles-du-clown.book
# 1893_Marie-Delorme_Les-Filles-du-clown.book
# 1884_Gouraud-Julie_Le-Vieux-chateau.book
# 1884_Gouraud-Julie_Le-Vieux-chateau.book
# 1884_Gouraud-Julie_Le-Vieux-chateau.book
# 1884_Gouraud-Julie_Le-Vieux-chateau.book
# 1884_Gouraud-Julie_Le-Vieux-chateau.book
# 1880_Gozlan-Leon_Aventures-merveilleuses-et-touchantes-du-prince-Chenevis-et-de-sa-jeune-soeur.book
# 1880_Gozlan-Leon_Aventures-merveilleuses-et-touchantes-du-prince-Chenevis-et-de-sa-jeune-soeur.book
# 1880_Gozlan-Leon_Aventures-merveilleuses-et-touchantes-du-prince-Chenevis-et-de-sa-jeune-soeur.book
# 1880_Gozlan-Leon_Aventures-merveilleuses-et-touchantes-du-prince-Chenevis-et-de-sa-jeune-soeur.book
# 1880_Gozlan-Leon_Aventures-merveilleuses-et-touchantes-du-prince-Chenevis-et-de-sa-jeune-soeur.book
# 1862_Leneveux-Louise_Soirees-en-famille--lectures-pour-la-jeunesse.book
# 1862_Leneveux-Louise_Soirees-en-famille--lectures-pour-la-jeunesse.book
# 1862_Leneveux-Louise_Soirees-en-famille--lectures-pour-la-jeunesse.book
# 1862_Leneveux-Louise_Soirees-en-famille--lectures-pour-la-jeunesse.book
# 1862_Leneveux-Louise_Soirees-en-famille--lectures-pour-la-jeunesse.book
# 1846_Musset-Paul-de_Monsieur-le-Vent-et-Madame-la-Pluie.book
# 1846_Musset-Paul-de_Monsieur-le-Vent-et-Madame-la-Pluie.book
# 1846_Musset-Paul-de_Monsieur-le-Vent-et-Madame-la-Pluie.book
# 1846_Musset-Paul-de_Monsieur-le-Vent-et-Madame-la-Pluie.book
# 1846_Musset-Paul-de_Monsieur-le-Vent-et-Madame-la-Pluie.book
# 1873_Sannois-Comtesse-de_Les-Soirees-a-la-maison.book
# 1873_Sannois-Comtesse-de_Les-Soirees-a-la-maison.book
# 1873_Sannois-Comtesse-de_Les-Soirees-a-la-maison.book
# 1873_Sannois-Comtesse-de_Les-Soirees-a-la-maison.book
# 1873_Sannois-Comtesse-de_Les-Soirees-a-la-maison.book
# 1858_Pressense-Elise-de_Rosa.book
# 1858_Pressense-Elise-de_Rosa.book
# 1858_Pressense-Elise-de_Rosa.book
# 1858_Pressense-Elise-de_Rosa.book
# 1858_Pressense-Elise-de_Rosa.book
# 1835_Woillez-Catherine_Le-Robinson-des-demoiselles.book
# 1835_Woillez-Catherine_Le-Robinson-des-demoiselles.book
# 1835_Woillez-Catherine_Le-Robinson-des-demoiselles.book
# 1835_Woillez-Catherine_Le-Robinson-des-demoiselles.book
# 1835_Woillez-Catherine_Le-Robinson-des-demoiselles.book
# 1880_Fleuriot-Zenaide_Tranquille-et-Tourbillon.book
# 1880_Fleuriot-Zenaide_Tranquille-et-Tourbillon.book
# 1880_Fleuriot-Zenaide_Tranquille-et-Tourbillon.book
# 1880_Fleuriot-Zenaide_Tranquille-et-Tourbillon.book
# 1880_Fleuriot-Zenaide_Tranquille-et-Tourbillon.book
# 1878_Assollant-Alfred_Le-plus-hardi-des-gueux.book
# 1878_Assollant-Alfred_Le-plus-hardi-des-gueux.book
# 1878_Assollant-Alfred_Le-plus-hardi-des-gueux.book
# 1878_Assollant-Alfred_Le-plus-hardi-des-gueux.book
# 1878_Assollant-Alfred_Le-plus-hardi-des-gueux.book
# 1861_Segur-comtesse-de_Pauvre-Blaise.book
# 1861_Segur-comtesse-de_Pauvre-Blaise.book
# 1861_Segur-comtesse-de_Pauvre-Blaise.book
# 1861_Segur-comtesse-de_Pauvre-Blaise.book
# 1861_Segur-comtesse-de_Pauvre-Blaise.book
# 1891_Pitray-Olga-de-Segur_L-Usine-et-le-chateau.book
# 1891_Pitray-Olga-de-Segur_L-Usine-et-le-chateau.book
# 1891_Pitray-Olga-de-Segur_L-Usine-et-le-chateau.book
# 1891_Pitray-Olga-de-Segur_L-Usine-et-le-chateau.book
# 1891_Pitray-Olga-de-Segur_L-Usine-et-le-chateau.book
# 1890_Dombre-Roger_La-Nounou.book
# 1890_Dombre-Roger_La-Nounou.book
# 1890_Dombre-Roger_La-Nounou.book
# 1890_Dombre-Roger_La-Nounou.book
# 1890_Dombre-Roger_La-Nounou.book
# 1867_Marcel-Jeanne_Les-petits-vagabonds.book
# 1867_Marcel-Jeanne_Les-petits-vagabonds.book
# 1867_Marcel-Jeanne_Les-petits-vagabonds.book
# 1867_Marcel-Jeanne_Les-petits-vagabonds.book
# 1867_Marcel-Jeanne_Les-petits-vagabonds.book
# 1869_Carraud-Zulma-Tourangin-Mme_Les-Gouters-de-la-grand-mere.book
# 1869_Carraud-Zulma-Tourangin-Mme_Les-Gouters-de-la-grand-mere.book
# 1869_Carraud-Zulma-Tourangin-Mme_Les-Gouters-de-la-grand-mere.book
# 1869_Carraud-Zulma-Tourangin-Mme_Les-Gouters-de-la-grand-mere.book
# 1869_Carraud-Zulma-Tourangin-Mme_Les-Gouters-de-la-grand-mere.book
# 1854_Dumas-Alexandre_La-jeunesse-de-Pierrot.book
# 1854_Dumas-Alexandre_La-jeunesse-de-Pierrot.book
# 1854_Dumas-Alexandre_La-jeunesse-de-Pierrot.book
# 1854_Dumas-Alexandre_La-jeunesse-de-Pierrot.book
# 1854_Dumas-Alexandre_La-jeunesse-de-Pierrot.book
# 1863_Segur-comtesse-de_Les-deux-nigauds.book
# 1863_Segur-comtesse-de_Les-deux-nigauds.book
# 1863_Segur-comtesse-de_Les-deux-nigauds.book
# 1863_Segur-comtesse-de_Les-deux-nigauds.book
# 1863_Segur-comtesse-de_Les-deux-nigauds.book
# 1866_Gouraud-Julie_Mémoires-d'un-caniche.book
# 1866_Gouraud-Julie_Mémoires-d'un-caniche.book
# 1866_Gouraud-Julie_Mémoires-d'un-caniche.book
# 1866_Gouraud-Julie_Mémoires-d'un-caniche.book
# 1866_Gouraud-Julie_Mémoires-d'un-caniche.book
# 1884_Laurie-Andre_L-Heritier-de-Robinson.book
# 1884_Laurie-Andre_L-Heritier-de-Robinson.book
# 1884_Laurie-Andre_L-Heritier-de-Robinson.book
# 1884_Laurie-Andre_L-Heritier-de-Robinson.book
# 1884_Laurie-Andre_L-Heritier-de-Robinson.book
# 1890_Pitray-Olga-de-Segur_Voyages-abracadabrants-du-gros-Phileas.book
# 1890_Pitray-Olga-de-Segur_Voyages-abracadabrants-du-gros-Phileas.book
# 1890_Pitray-Olga-de-Segur_Voyages-abracadabrants-du-gros-Phileas.book
# 1890_Pitray-Olga-de-Segur_Voyages-abracadabrants-du-gros-Phileas.book
# 1890_Pitray-Olga-de-Segur_Voyages-abracadabrants-du-gros-Phileas.book
# 1888_Stolz-Madame-de_Violence-et-bonte.book
# 1888_Stolz-Madame-de_Violence-et-bonte.book
# 1888_Stolz-Madame-de_Violence-et-bonte.book
# 1888_Stolz-Madame-de_Violence-et-bonte.book
# 1888_Stolz-Madame-de_Violence-et-bonte.book
# 1886_Lemonnier-Camille_Les-joujoux-parlants.book
# 1886_Lemonnier-Camille_Les-joujoux-parlants.book
# 1886_Lemonnier-Camille_Les-joujoux-parlants.book
# 1886_Lemonnier-Camille_Les-joujoux-parlants.book
# 1886_Lemonnier-Camille_Les-joujoux-parlants.book
# 1877_Fleuriot-Zenaide_Un-enfant-gate.book
# 1877_Fleuriot-Zenaide_Un-enfant-gate.book
# 1877_Fleuriot-Zenaide_Un-enfant-gate.book
# 1877_Fleuriot-Zenaide_Un-enfant-gate.book
# 1877_Fleuriot-Zenaide_Un-enfant-gate.book
# 1905_Toulet-Paul-Jean_Mon-amie-Nane.book
# 1905_Toulet-Paul-Jean_Mon-amie-Nane.book
# 1905_Toulet-Paul-Jean_Mon-amie-Nane.book
# 1905_Toulet-Paul-Jean_Mon-amie-Nane.book
# 1905_Toulet-Paul-Jean_Mon-amie-Nane.book
# 1930_Genestoux-Magdeleine-du_Mademoiselle-trouble-fete.book
# 1930_Genestoux-Magdeleine-du_Mademoiselle-trouble-fete.book
# 1930_Genestoux-Magdeleine-du_Mademoiselle-trouble-fete.book
# 1930_Genestoux-Magdeleine-du_Mademoiselle-trouble-fete.book
# 1930_Genestoux-Magdeleine-du_Mademoiselle-trouble-fete.book
# 1885_Malot-Hector_Romain-Kalbris.book
# 1885_Malot-Hector_Romain-Kalbris.book
# 1885_Malot-Hector_Romain-Kalbris.book
# 1885_Malot-Hector_Romain-Kalbris.book
# 1885_Malot-Hector_Romain-Kalbris.book
# 1864_Ribelle-Charles-de_Les-Confidences-de-Gribouille.book
# 1864_Ribelle-Charles-de_Les-Confidences-de-Gribouille.book
# 1864_Ribelle-Charles-de_Les-Confidences-de-Gribouille.book
# 1864_Ribelle-Charles-de_Les-Confidences-de-Gribouille.book
# 1864_Ribelle-Charles-de_Les-Confidences-de-Gribouille.book
# 1892_Stolz-Madame-de_La-famille-Coquelicot.book
# 1892_Stolz-Madame-de_La-famille-Coquelicot.book
# 1892_Stolz-Madame-de_La-famille-Coquelicot.book
# 1892_Stolz-Madame-de_La-famille-Coquelicot.book
# 1892_Stolz-Madame-de_La-famille-Coquelicot.book
# 1881_Martignat-Mlle-de_Ginette.book
# 1881_Martignat-Mlle-de_Ginette.book
# 1881_Martignat-Mlle-de_Ginette.book
# 1881_Martignat-Mlle-de_Ginette.book
# 1881_Martignat-Mlle-de_Ginette.book
# 1943_Saint-Exupery-Antoine-de_Le-petit-prince.book
# 1943_Saint-Exupery-Antoine-de_Le-petit-prince.book
# 1943_Saint-Exupery-Antoine-de_Le-petit-prince.book
# 1943_Saint-Exupery-Antoine-de_Le-petit-prince.book
# 1943_Saint-Exupery-Antoine-de_Le-petit-prince.book
# 1877_Bruno-G_Le_Tour_de_la_France_par_deux_enfants.book
# 1877_Bruno-G_Le_Tour_de_la_France_par_deux_enfants.book
# 1877_Bruno-G_Le_Tour_de_la_France_par_deux_enfants.book
# 1877_Bruno-G_Le_Tour_de_la_France_par_deux_enfants.book
# 1877_Bruno-G_Le_Tour_de_la_France_par_deux_enfants.book
# 1886_Sand-George_Les-ailes-de-courage.book
# 1886_Sand-George_Les-ailes-de-courage.book
# 1886_Sand-George_Les-ailes-de-courage.book
# 1886_Sand-George_Les-ailes-de-courage.book
# 1886_Sand-George_Les-ailes-de-courage.book
# 1852_Carraud-Zulma-Tourangin-Mme_La-petite-Jeanne.book
# 1852_Carraud-Zulma-Tourangin-Mme_La-petite-Jeanne.book
# 1852_Carraud-Zulma-Tourangin-Mme_La-petite-Jeanne.book
# 1852_Carraud-Zulma-Tourangin-Mme_La-petite-Jeanne.book
# 1852_Carraud-Zulma-Tourangin-Mme_La-petite-Jeanne.book
# 1881_Erckmann-Chatrian_Les-Vieux-de-la-Vieille-Justine-et-Lucien..book
# 1881_Erckmann-Chatrian_Les-Vieux-de-la-Vieille-Justine-et-Lucien..book
# 1881_Erckmann-Chatrian_Les-Vieux-de-la-Vieille-Justine-et-Lucien..book
# 1881_Erckmann-Chatrian_Les-Vieux-de-la-Vieille-Justine-et-Lucien..book
# 1881_Erckmann-Chatrian_Les-Vieux-de-la-Vieille-Justine-et-Lucien..book
# 1881_Laurie-Andre_Memoires-d-un-collegien.book
# 1881_Laurie-Andre_Memoires-d-un-collegien.book
# 1881_Laurie-Andre_Memoires-d-un-collegien.book
# 1881_Laurie-Andre_Memoires-d-un-collegien.book
# 1881_Laurie-Andre_Memoires-d-un-collegien.book
# 1860_Sauquet-Aricie-Courbatere-Mme_Les-Veillees-du-pensionnat.book
# 1860_Sauquet-Aricie-Courbatere-Mme_Les-Veillees-du-pensionnat.book
# 1860_Sauquet-Aricie-Courbatere-Mme_Les-Veillees-du-pensionnat.book
# 1860_Sauquet-Aricie-Courbatere-Mme_Les-Veillees-du-pensionnat.book
# 1860_Sauquet-Aricie-Courbatere-Mme_Les-Veillees-du-pensionnat.book
# 1878_Girardin-Jules_Ouida-Pascarel-roman-imite-de-l-anglais.book
# 1878_Girardin-Jules_Ouida-Pascarel-roman-imite-de-l-anglais.book
# 1878_Girardin-Jules_Ouida-Pascarel-roman-imite-de-l-anglais.book
# 1878_Girardin-Jules_Ouida-Pascarel-roman-imite-de-l-anglais.book
# 1878_Girardin-Jules_Ouida-Pascarel-roman-imite-de-l-anglais.book
# 1893_Vadier-Berthe_Rose-et-Rosette-odyssee-d-une-trop-belle-poupee.book
# 1893_Vadier-Berthe_Rose-et-Rosette-odyssee-d-une-trop-belle-poupee.book
# 1893_Vadier-Berthe_Rose-et-Rosette-odyssee-d-une-trop-belle-poupee.book
# 1893_Vadier-Berthe_Rose-et-Rosette-odyssee-d-une-trop-belle-poupee.book
# 1893_Vadier-Berthe_Rose-et-Rosette-odyssee-d-une-trop-belle-poupee.book
# 1894_Gautier-Judith_Memoires-d-un-Elephant-blanc.book
# 1894_Gautier-Judith_Memoires-d-un-Elephant-blanc.book
# 1894_Gautier-Judith_Memoires-d-un-Elephant-blanc.book
# 1894_Gautier-Judith_Memoires-d-un-Elephant-blanc.book
# 1894_Gautier-Judith_Memoires-d-un-Elephant-blanc.book
# 1867_Gouraud-Julie_Le-petit-colporteur.book
# 1867_Gouraud-Julie_Le-petit-colporteur.book
# 1867_Gouraud-Julie_Le-petit-colporteur.book
# 1867_Gouraud-Julie_Le-petit-colporteur.book
# 1867_Gouraud-Julie_Le-petit-colporteur.book
# 1896_Soboleska-Mme_Siribeddi-memoires-d-un-elephant.book
# 1896_Soboleska-Mme_Siribeddi-memoires-d-un-elephant.book
# 1896_Soboleska-Mme_Siribeddi-memoires-d-un-elephant.book
# 1896_Soboleska-Mme_Siribeddi-memoires-d-un-elephant.book
# 1896_Soboleska-Mme_Siribeddi-memoires-d-un-elephant.book
# 1865_Kaempfen-Albert_La-Tasse-a-the.book
# 1865_Kaempfen-Albert_La-Tasse-a-the.book
# 1865_Kaempfen-Albert_La-Tasse-a-the.book
# 1865_Kaempfen-Albert_La-Tasse-a-the.book
# 1865_Kaempfen-Albert_La-Tasse-a-the.book
# 1873_Viollet-le-Duc-Eugene-Emmanuel_Histoire-d-une-maison.book
# 1873_Viollet-le-Duc-Eugene-Emmanuel_Histoire-d-une-maison.book
# 1873_Viollet-le-Duc-Eugene-Emmanuel_Histoire-d-une-maison.book
# 1873_Viollet-le-Duc-Eugene-Emmanuel_Histoire-d-une-maison.book
# 1873_Viollet-le-Duc-Eugene-Emmanuel_Histoire-d-une-maison.book
# 1899_Colomb-Josephine_Chloris-et-Jeanneton.book
# 1899_Colomb-Josephine_Chloris-et-Jeanneton.book
# 1899_Colomb-Josephine_Chloris-et-Jeanneton.book
# 1899_Colomb-Josephine_Chloris-et-Jeanneton.book
# 1899_Colomb-Josephine_Chloris-et-Jeanneton.book
# 1880_Gouraud-Julie_Aller-et-retour.book
# 1880_Gouraud-Julie_Aller-et-retour.book
# 1880_Gouraud-Julie_Aller-et-retour.book
# 1880_Gouraud-Julie_Aller-et-retour.book
# 1880_Gouraud-Julie_Aller-et-retour.book
# 1876_Gouraud-Julie_Les-Quatre-pièces-d'or.book
# 1876_Gouraud-Julie_Les-Quatre-pièces-d'or.book
# 1876_Gouraud-Julie_Les-Quatre-pièces-d'or.book
# 1876_Gouraud-Julie_Les-Quatre-pièces-d'or.book
# 1876_Gouraud-Julie_Les-Quatre-pièces-d'or.book
# 1848_Woillez-Catherine_Edma-et-Marguerite-ou-les-Ruines-de-Chatillon-d-Azergues.book
# 1848_Woillez-Catherine_Edma-et-Marguerite-ou-les-Ruines-de-Chatillon-d-Azergues.book
# 1848_Woillez-Catherine_Edma-et-Marguerite-ou-les-Ruines-de-Chatillon-d-Azergues.book
# 1848_Woillez-Catherine_Edma-et-Marguerite-ou-les-Ruines-de-Chatillon-d-Azergues.book
# 1848_Woillez-Catherine_Edma-et-Marguerite-ou-les-Ruines-de-Chatillon-d-Azergues.book
# 1892_Colomb-Josephine_Les-Conquetes-d-Hermine.book
# 1892_Colomb-Josephine_Les-Conquetes-d-Hermine.book
# 1892_Colomb-Josephine_Les-Conquetes-d-Hermine.book
# 1892_Colomb-Josephine_Les-Conquetes-d-Hermine.book
# 1892_Colomb-Josephine_Les-Conquetes-d-Hermine.book
# 1867_Segur-comtesse-de_Le-Mauvais-Genie.book
# 1867_Segur-comtesse-de_Le-Mauvais-Genie.book
# 1867_Segur-comtesse-de_Le-Mauvais-Genie.book
# 1867_Segur-comtesse-de_Le-Mauvais-Genie.book
# 1867_Segur-comtesse-de_Le-Mauvais-Genie.book
# 1881_Stolz-Madame-de_Les-deux-reines.book
# 1881_Stolz-Madame-de_Les-deux-reines.book
# 1881_Stolz-Madame-de_Les-deux-reines.book
# 1881_Stolz-Madame-de_Les-deux-reines.book
# 1881_Stolz-Madame-de_Les-deux-reines.book
# 1890_Hameau-Louise_Mademoiselle-Pourquoi.book
# 1890_Hameau-Louise_Mademoiselle-Pourquoi.book
# 1890_Hameau-Louise_Mademoiselle-Pourquoi.book
# 1890_Hameau-Louise_Mademoiselle-Pourquoi.book
# 1890_Hameau-Louise_Mademoiselle-Pourquoi.book
# 1901_Soboleska-Mme_Les-Bonnes-idees-de-Mlle-Rose_Les-Enfants-au-ballon-elastique.book
# 1901_Soboleska-Mme_Les-Bonnes-idees-de-Mlle-Rose_Les-Enfants-au-ballon-elastique.book
# 1901_Soboleska-Mme_Les-Bonnes-idees-de-Mlle-Rose_Les-Enfants-au-ballon-elastique.book
# 1901_Soboleska-Mme_Les-Bonnes-idees-de-Mlle-Rose_Les-Enfants-au-ballon-elastique.book
# 1901_Soboleska-Mme_Les-Bonnes-idees-de-Mlle-Rose_Les-Enfants-au-ballon-elastique.book
# 1878_Berthet-Elie_Les-Petits-ecoliers-dans-les-cinq-parties-du-monde.book
# 1878_Berthet-Elie_Les-Petits-ecoliers-dans-les-cinq-parties-du-monde.book
# 1878_Berthet-Elie_Les-Petits-ecoliers-dans-les-cinq-parties-du-monde.book
# 1878_Berthet-Elie_Les-Petits-ecoliers-dans-les-cinq-parties-du-monde.book
# 1878_Berthet-Elie_Les-Petits-ecoliers-dans-les-cinq-parties-du-monde.book
# 1833_Girardin-Delphine-de_Contes-d-une-vieille-fille-a-ses-neveux.book
# 1833_Girardin-Delphine-de_Contes-d-une-vieille-fille-a-ses-neveux.book
# 1833_Girardin-Delphine-de_Contes-d-une-vieille-fille-a-ses-neveux.book
# 1833_Girardin-Delphine-de_Contes-d-une-vieille-fille-a-ses-neveux.book
# 1833_Girardin-Delphine-de_Contes-d-une-vieille-fille-a-ses-neveux.book
# 1867_Savigny-Laurence-de_Le-Robinson-des-Alpes.book
# 1867_Savigny-Laurence-de_Le-Robinson-des-Alpes.book
# 1867_Savigny-Laurence-de_Le-Robinson-des-Alpes.book
# 1867_Savigny-Laurence-de_Le-Robinson-des-Alpes.book
# 1867_Savigny-Laurence-de_Le-Robinson-des-Alpes.book

# %%
print(df.head())
print(df.shape)   # dovrebbe essere (600, 4)
# Out:
#                                                title author_gender  Gender  \
# 0  1883_Halt-Marie-Robert_Histoire-d-un-petit-hom...                     0
# 1  1883_Halt-Marie-Robert_Histoire-d-un-petit-hom...                     0
# 2  1883_Halt-Marie-Robert_Histoire-d-un-petit-hom...                     1
# 3  1883_Halt-Marie-Robert_Histoire-d-un-petit-hom...                     0
# 4  1883_Halt-Marie-Robert_Histoire-d-un-petit-hom...                     1
#
#   type                                               text
# 0       remplir humer répondre avoir ajouter souffrir ...
# 1       manger entrer penser trouver passer dire prête...
# 2       venir ébrouer obéir acheter rire garder ajoute...
# 3       devenir connaître tirer ouvrir donner reprendr...
# 4       arriver répondre entendre répondre écouter saî...
# (615, 5)

# %%
df.to_csv("tf-idf_personnages.csv", index=False, encoding="utf-8")

# %% [markdown]
# ## Ricaricare il file per le analisi successive

# %% [markdown]
# Avere cura di passare le annotazioni con lo script (cartella Utilities)

# %%
import pandas as pd

df = pd.read_csv("/Users/deniseatzori/Library/Mobile Documents/com~apple~CloudDocs/ENC-PSL/Memoire/Github_tesi/tf-idf_personnages_ann.csv")

# %%
# creation d'un nouveau dataframe ne contenant que les types 0 (adult) et 1 (enfant)
df = df[df["type"].isin([0,1])]

# %%
# suppression de la colonne des titres et des celles du genre
df.drop(columns=["title", "Gender","author_gender"], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    type                                               text
# 0   1.0  remplir humer répondre avoir ajouter souffrir ...
# 1   0.0  manger entrer penser trouver passer dire prête...
# 2   1.0  venir ébrouer obéir acheter rire garder ajoute...
# 3   0.0  devenir connaître tirer ouvrir donner reprendr...
# 4   1.0  arriver répondre entendre répondre écouter saî...

# %%
documents = df["text"].tolist()
y = df["type"].tolist()

# %% [markdown]
# ## Creazione matrice TF-IDF

# %% [markdown]
# Dato che lavoro su personaggi, potrebbe essere utile:
#
# min_df=2 o 3
# max_df=0.8
#
# Perché:
#
# - elimina parole che compaiono in un solo personaggio
# - elimina parole troppo comuni (tipo "faire", "dire", "être")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(min_df=2)
X_tfidf = vectorizer.fit_transform(documents)

# %% [markdown]
# ## Addestramento SVM sulle classi di età

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, StratifiedKFold

# 1. Inizializza il modello SVM
# Usiamo un kernel lineare, solitamente il più efficace per il testo
svm_model = SVC(kernel='rbf', C=1.0)

# 2. Configura il metodo di splitting (StratifiedKFold è ideale per mantenere le proporzioni delle classi)
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 3. Esegui la Cross Validation
# Calcoliamo l'accuratezza su 5 "fold" diversi
scores = cross_val_score(svm_model, X_tfidf, y, cv=skf, scoring='accuracy')

# 4. Risultati
print(f"Accuratezza media: {scores.mean():.4f}")
print(f"Deviazione standard: {scores.std():.4f}")
print(f"Punteggi per ogni fold: {scores}")
# Out:
# Accuratezza media: 0.8542
# Deviazione standard: 0.0353
# Punteggi per ogni fold: [0.9        0.87272727 0.87272727 0.80909091 0.81651376]

# %%
from sklearn.model_selection import cross_validate

scoring = ['precision', 'recall', 'f1']

results = cross_validate(svm_model, X_tfidf, y, cv=skf, scoring=scoring)

print(f"Precision media: {results['test_precision'].mean():.4f}")
print(f"Recall medio: {results['test_recall'].mean():.4f}")
print(f"F1 medio: {results['test_f1'].mean():.4f}")
# Out:
# Precision media: 0.8672
# Recall medio: 0.8423
# F1 medio: 0.8510

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- 2. Addestramento Finale ---
svm_model.fit(X_tfidf, y)

# --- 3. Estrazione Feature Importance ---
# Otteniamo i pesi (coefficienti) e i nomi delle parole
coefs = svm_model.coef_.toarray()[0]
feature_names = np.array(vectorizer.get_feature_names_out())

# Creiamo un DataFrame per manipolare i dati facilmente
importance_df = pd.DataFrame({'word': feature_names, 'weight': coefs})

# --- 4. Selezione delle parole chiave per ogni classe ---
# Supponiamo: Classe 0 (es. Maschio) e Classe 1 (es. Femmina)
# I pesi negativi spingono verso la Classe 0, quelli positivi verso la Classe 1
top_class_1 = importance_df.sort_values(by='weight', ascending=False).head(15)
top_class_0 = importance_df.sort_values(by='weight', ascending=True).head(15)

# Uniamo per il grafico
top_features = pd.concat([top_class_1, top_class_0])

# --- 5. Visualizzazione ---
plt.figure(figsize=(10, 10))
colors = ['skyblue' if w > 0 else 'salmon' for w in top_features['weight']]
plt.barh(top_features['word'], top_features['weight'], color=colors)
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel("Poids des coefficients (SVM linéaire)")
plt.title("Importance des caractéristiques : Mots les plus discriminatoires (genre)")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier # Cambiato qui
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
import pandas as pd

# 1. Creazione della Pipeline
# Nota: RandomForest non richiede scaling, ma lo teniamo per coerenza con la tua struttura
clf_pipeline = make_pipeline(
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

# 2. Calcolo dell'accuratezza media con Cross-Validation
scores = cross_val_score(clf_pipeline, X_tfidf, y, cv=5, n_jobs=-1)
print(f"Accuratezza media (Random Forest): {scores.mean():.3f}")

# 3. Ottenere predizioni per la Matrice di Confusione
Y_pred = cross_val_predict(clf_pipeline, X_tfidf, y, cv=5, n_jobs=-1)
cm = confusion_matrix(y, Y_pred)

# Visualizzazione Matrice di Confusione
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Greens') # Cambiato colore in verde, tipico dei Forest
# --- Analisi dell'Importanza delle Feature ---

# Suddivisione Train/Validation
X_train, X_val, y_train, y_val = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Addestramento
clf_pipeline.fit(X_train, y_train)
# Out:
# Accuratezza media (Random Forest): 0.778
# Pipeline(steps=[('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=-1, random_state=42))])

# %%
from sklearn.model_selection import cross_validate

scoring = ['precision', 'recall', 'f1']

results = cross_validate(clf_pipeline, X_tfidf, y, cv=skf, scoring=scoring)

print(f"Precision media: {results['test_precision'].mean():.4f}")
print(f"Recall medio: {results['test_recall'].mean():.4f}")
print(f"F1 medio: {results['test_f1'].mean():.4f}")
# Out:
# Precision media: 0.8122
# Recall medio: 0.7982
# F1 medio: 0.8027

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedKFold

# 1. Inizializza il modello
logreg_model = LogisticRegression(max_iter=1000)

# 2. Configura lo splitting
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 3. Cross Validation
scores = cross_val_score(logreg_model, X_tfidf, y, cv=skf, scoring='accuracy')

# 4. Risultati
print(f"Accuratezza media: {scores.mean():.4f}")
print(f"Deviazione standard: {scores.std():.4f}")
print(f"Punteggi per ogni fold: {scores}")
# Out:
# Accuratezza media: 0.8469
# Deviazione standard: 0.0505
# Punteggi per ogni fold: [0.9        0.9        0.85454545 0.77272727 0.80733945]
